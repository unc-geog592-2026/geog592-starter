# %% [markdown]
# # GEOG 592 — Week 1: First Notebook
#
# **Purpose:** Practice the basic Colab workflow you will use in this course.
#
# By the end of this activity, you should be able to:
#
# - run a code cell;
# - edit code and run it again;
# - distinguish between **code cells** and **Markdown/text cells**;
# - add a new code cell;
# - add a new Markdown cell;
# - rename a notebook;
# - save the notebook to your GitHub repository; and
# - verify that the notebook appears correctly on GitHub.
#
# **This is just a practice exercise to help you learn the workflow.**

# %% [markdown]
# ## 1. Student information
#
# Edit this Markdown cell and enter your information.
#
# **Name:**
# **ONYEN:**
# **GitHub username:**

# %% [markdown]
# ## 2. Run your first code cell
#
# A **code cell** contains Python instructions.
#
# Click the play button on the left side of the cell below, or press **Shift + Enter**, to run it.

# %%
course = "GEOG 592"
semester = "Fall 2026"

print(course)
print(semester)
# Out:
# GEOG 592
# Fall 2026

# %% [markdown]
# ## 3. Edit and rerun code
#
# Change the value of `distance_meters` below from `100` to another number.
#
# Then run the cell again and observe how the output changes.

# %%
distance_meters = 100
number_of_segments = 4

total_distance = distance_meters * number_of_segments

print("Distance per segment:", distance_meters, "meters")
print("Number of segments:", number_of_segments)
print("Total distance:", total_distance, "meters")
# Out:
# Distance per segment: 100 meters
# Number of segments: 4
# Total distance: 400 meters

# %% [markdown]
# ## 4. Make another change
#
# The list below contains the names of several common GIS operations.
#
# 1. Run the cell.
# 2. Add a new GIS operation that you have used before.
# 3. Run the cell again.

# %%
gis_operations = ["buffer", "clip", "join", "reproject"]

print(gis_operations)
# Out:
# ['buffer', 'clip', 'join', 'reproject']

# %% [markdown]
# ## 5. Add a new code cell
#
# Create a **new code cell** directly below this one.
#
# In the new cell, type:
#
# ```python
# my_number = 5
# print(my_number * 10)
# ```
#
# Run your new cell.
#
# Hint: Do **not** add the code inside this Markdown cell. Create a new code cell.

# %% [markdown]
# ## 6. Add a new Markdown cell
#
# Create a **new Markdown/text cell** directly below your new code cell.
#
# In that cell, write:
#
# 1. your name in **bold font**;
# 2. one GIS task you would like to learn how to automate; and
# 3. one sentence describing the difference between a code cell and a Markdown cell.

# %% [markdown]
# ## 7. Rename the notebook
#
# Rename this notebook using the following convention:
#
# `YOURONYEN_week01.ipynb`
#
# For example,
#
# `jgarcia_week01.ipynb`

# %% [markdown]
# ## 8. Save the notebook to GitHub
#
# After completing the activity:
#
# 1. In Colab, choose **File → Save a copy in GitHub**.
# 2. Select your GEOG 592 repository.
# 3. Save the notebook in the `week01` folder.
# 4. Return to GitHub.
# 5. Open the `week01` folder.
# 6. Verify that your `.ipynb` file appears.
# 7. Open the notebook on GitHub and confirm that your changes are visible.
#
# ### Before you finish
#
# Confirm that:
#
# - your student information is complete;
# - you changed and reran at least one code cell;
# - you added one new code cell;
# - you added one new Markdown cell;
# - the notebook has the correct filename; and
# - the notebook appears in your GitHub repository.
#
# One more thing:
# - before Monday August 24, 2026:
#     - create a folder named `data` inside folder `week01`
#     - inside the folder `week01 > data` save a geojson file and push it to your Github
#     - the geojson can be downloaded from another place or created by you, but it has to be less than 1MB in size.
#     - the geojson needs to be titled `YOURONYEN_week01_vector.geojson`
